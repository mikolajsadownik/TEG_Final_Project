# %%
import pandas as pd
from rapidfuzz import fuzz, process
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from keywordmaker import KeyWordMaker

# %%
import torch
import transformers

print(torch.__version__)
print(transformers.__version__)
# Out:
# 2.7.0+cpu
# 4.51.3

# %%
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# %%
with open(r"C:\Users\jarja\Desktop\Studia\teg\TEG_Final_Project\MOJtest\acts_backup.json", "r", encoding="utf-8") as f:
    data = [json.loads(line) for line in f]

# %%
df=pd.DataFrame(data)

# %%
print(np.shape(df))
# Out:
# (28807, 32)

# %%
collumtoTransfer=['title','keywords','type','address','displayAddress',"texts"]
newdf = pd.DataFrame()
newdf[collumtoTransfer]=df[collumtoTransfer]

# %%
fileNames = []
fileTypes = []

for files in newdf["texts"]:
    pliki_T = [t["fileName"] for t in files if t.get("type") == "T"]
    pliki_O = [t["fileName"] for t in files if t.get("type") == "O"]
    if pliki_T:
        fileNames.append(pliki_T)       # lista plików T
        fileTypes.append("T")
    elif pliki_O:
        fileNames.append(pliki_O)       # lista plików O
        fileTypes.append("O")
    else:
        fileNames.append([])            # brak plików T/O
        fileTypes.append("brak")

# Dodanie kolumn do DataFrame
newdf["fileNames"] = fileNames
newdf["typeFile"] = fileTypes
print(fileNames)
# Out:
# [['D20250611L.pdf'], ['D20250610L.pdf'], ['D20250609.pdf'], ['D20250608L.pdf'], ['D20250607L.pdf'], ['D20250606.pdf'], ['D20250605.pdf'], ['D20250604.pdf'], ['D20250603L.pdf'], ['D20250602L.pdf'], ['D20250600.pdf'], ['D20250599.pdf'], ['D20250598.pdf'], ['D20250597.pdf'], ['D20250596.pdf'], ['D20250595L.pdf'], ['D20250594L.pdf'], ['D20250592L.pdf'], ['D20250591.pdf'], ['D20250590L.pdf'], ['D20250589.pdf'], ['D20250588.pdf'], ['D20250587.pdf'], ['D20250586.pdf'], ['D20250585.pdf'], ['D20250584.pdf'], ['D20250583.pdf'], ['D20250582.pdf'], ['D20250581L.pdf'], ['D20250580.pdf'], ['D20250579.pdf'], ['D20250578.pdf'], ['D20250577.pdf'], ['D20250576.pdf'], ['D20250575.pdf'], ['D20250574.pdf'], ['D20250573L.pdf'], ['D20250572L.pdf'], ['D20250571.pdf'], ['D20250570L.pdf'], ['D20250569.pdf'], ['D20250568L.pdf'], ['D20250567L.pdf'], ['D20250566L.pdf'], ['D20250565L.pdf'], ['D20250564.pdf'], ['D20250563.pdf'], ['D20250562.pdf'], ['D20250561L.pdf'], ['D20250560L.pdf'], ['D20250559L.pdf'], ['D20250558.pdf'], ['D20250557.pdf'], ['D20250556.pdf'], ['D20250555L.pdf'], ['D20250554.pdf'], ['D20250553.pdf'], ['D20250552.pdf'], ['D20250551.pdf'], ['D20250550.pdf'], ['D20250549.pdf'], ['D20250548.pdf'], ['D20250547.pdf'], ['D20250546.pdf'], ['D20250545.pdf'], ['D20250544.pdf'], ['D20250542.pdf'], ['D20250540.pdf'], ['D20
407.pdf'], ['D20250406.pdf'], ['D20250405.pdf'], ['D20250404.pdf'], ['D20250403.pdf'], ['D20250402.pdf'], ['D20250401.pdf'], ['D20250400.pdf'], ['D20250399.pdf'], ['D20250398.pdf'], ['D20250397.pdf'], ['D20250396.pdf'], ['D20250395.pdf'], ['D20250394.pdf'], ['D20250393L.pdf'], ['D20250391.pdf'], ['D20250389L.pdf'], [ ...

# %%
print(newdf["fileNames"])
# Out:
# 0        [D20250611L.pdf]
# 1        [D20250610L.pdf]
# 2         [D20250609.pdf]
# 3        [D20250608L.pdf]
# 4        [D20250607L.pdf]
#                ...
# 28802     [M19470417.pdf]
# 28803     [M19460008.pdf]
# 28804     [M19390059.pdf]
# 28805     [M19340011.pdf]
# 28806     [M19340010.pdf]
# Name: fileNames, Length: 28807, dtype: object

# %%
# Usuwamy puste listy (len == 0)
newdf_ = newdf[newdf["keywords"].apply(lambda x: isinstance(x, list) and len(x) > 0)]
newdf_ = newdf_.reset_index(drop=True)

print(newdf_["keywords"])
numpyarray=newdf_["keywords"]
# Out:
# 0        [finansowa gospodarka, nadzór, sprawozdawczość...
# 1        [energetyczna gospodarka, energetyka, energety...
# 2        [żołnierz zawodowy, mieszkania funkcyjne, wojs...
# 3                                             [farmaceuci]
# 4        [przewozowe prawo, towary niebezpieczne, zezwo...
#                                ...
# 28273                                           [amnestia]
# 28274                                           [amnestia]
# 28275            [wydawnictwa i publikacje, prasowe prawo]
# 28276                         [izby rzemieślnicze, statut]
# 28277                         [izby rzemieślnicze, statut]
# Name: keywords, Length: 28278, dtype: object

# %%
texts = [' '.join(kw_list) for kw_list in newdf["keywords"]]

print(texts)
# Out:
# ['finansowa gospodarka nadzór sprawozdawczość elektroniczny instrument płatniczy działalność gospodarcza waluta agencje płatnicze usługi rachunkowość banki bankowe prawo stopa procentowa', 'energetyczna gospodarka energetyka energetyczne prawo', 'żołnierz zawodowy mieszkania funkcyjne wojsko lokalowe prawo', 'farmaceuci', '', 'przewozowe prawo towary niebezpieczne zezwolenia transport wojsko', 'kwalifikacje', 'farmaceutyczne prawo farmaceutyczne środki dokumenty leki i artykuły sanitarne dokumentacja medyczna', '', 'energetyczna gospodarka energetyka energetyczne prawo', 'umowy międzynarodowe ochrona środowiska', 'komornicy opłaty', 'narkomania', 'karne postępowanie cywilne postępowanie międzynarodowe prawo prywatne', 'żołnierz zawodowy dodatki do wynagrodzeń uposażenie', 'gry losowe i zakłady wzajemne', 'akta stanu cywilnego', 'instrumenty finansowe oferty', 'dyscyplinarne postępowanie rzecznicy patentowi aplikacja', 'rybacy morscy rybołówstwo morskie ryby', 'warunki sanitarne żywność i żywienie bezpieczeństwo produktów mięso produkcja', 'dokumenty', 'właściwość miejscowa siedziba wojsko prokuratura', 'transport kolejowy transport koleje', 'opakowania odpady', 'świadczenia lecznicze opieka zdrowotna', 'wynagrodzenia sądy powszechne stawki', 'szkolnictwo wyższe statki powietrzne lotnictwo cywilne', 'województwa administracja samorządowa samorząd terytorialny prawo miejscowe', 'sędziowie systemy teleinformatyczne', 'finansowanie oświata i wychowanie inwestycje remonty dotacje', 'dokumenty', 'biblioteki', 'ratownictwo świadczenia lecznicze', 'kopalnie monitoring geologiczne prawo', 'świadczenia lecznicze finansowanie opieka zdrowotna', 'księgi wieczyste i hipoteka kredyty i pożyczki', 'morza wyposażenie statki morskie', 'energetyczna gospodarka energetyka odnawialne źródła energii', 'umowa o pracę praca pracodawca pracownicy', 'nauka szkolnictwo wyższe inwestycje', 'przedsiębiorstwa nadzór rynek wewnętrzny działalność gospodarcza normalizacja normy', 'leśnictwo lasy', 'finansowa gospodarka kodeks karny zatrudnianie', 'energetyczna gospodarka energetyka', 'drób choroby zakaźne ochrona zwierząt choroby zwierząt', 'kwalifikacje farmaceuci', 'świadczenia lecznicze umowy opieka zdrowotna', 'drogi publiczne autostrady', 'wynagrodzenia jednostki budżetowe pracownicy urzędów państwowych', 'nieruchomości', 'obrona narodowa służba wojskowa żołnierzy służba wojskowa wojsko uposażenie', 'zwierzęta zwierzęta hodowlane stawki rolnictwo', 'farmaceutyczne prawo farmaceutyczne środki apteki leki i artykuły sanitarne', 'przymus bezpośredni broń palna', 'ewidencja pojazdy mechaniczne samochody', 'prawo o ruchu drogowym opłaty tablice rejestracyjne', 'finansowanie obiekty sportowe sport', 'zboża nasiennictwo i szkółkarstwo', 'finanse publiczne klasyfikacja', 'obrona narodowa psy zwierzęta', 'gospodarstwa rolne działalność gospodarcza rolnictwo pomoc finansowa', 'rolnicy działalność gospodarcza rolnictwo pomoc finansowa planowanie społeczno-gospodarcze', 'magazyny rolnictwo planowanie społeczno-gospodarcze', 'paliwa ekologia paliwa alternatywne biopaliwa', 'produkty rolne artykuły spożywcze ryby planowanie społeczno-gospodarcze', 'egzaminy kwalifikacje szkolnictwo zawodowe oświata i wychowanie', 'nauczyciele szkolnictwo artystyczne', 'łowieckie prawo', 'ordynacja podatkowa komornicy sądy powszechne urzędy i izby skarbowe', 'zabytki', 'emerytury i renty emerytalne programy', 'opieka zdrowotna', 'dodatki do wynagrodzeń funkcjonariusz publiczny', 'lekarze lekarze dentyści żołnierz zawodowy wojsko', 'ochrona osób i mienia', '', 'ministrowie nadzór obrona narodowa wyznania budownictwo geodezja i kartografia terenowe organy administracji rządowej przeciwpożarowa ochrona samorząd terytorialny naczelne i centralne organy administracji', 'wynagrodzenia zamówienia publiczne', 'górnictwo ochrona środowiska budownictwo mieszkaniowe planowanie przestrzenne geologiczne prawo', 'sądy powszechne sądy wojskowe', 'współpraca zagraniczna bankowe prawo', 'praca morza u ...

# %%
embededkeywors=model.encode(texts)

# %%
print(np.shape(embededkeywors))
avg_embedding = np.mean(embededkeywors, axis=0)
newdf["embeded"] = list(embededkeywors)

toche=['prawo pracy', 'umowa o prac�', 'pracodawca', 'dyscyplina pracy', 'dyscyplinarne post�powanie', 'kodeks pracy']

embeded=model.encode(toche)

toche_=np.mean(embeded, axis=0)
# Out:
# (28807, 384)

# %%
from sklearn.metrics.pairwise import cosine_similarity
def search_similar_documents(query_keywords, df, model, top_k=50):
    # Jeśli query_keywords jest listą słów, można zrobić join na string
    if isinstance(query_keywords, list):
        query_text = " ".join(query_keywords)
    else:
        query_text = query_keywords

    query_embedding = model.encode([query_text])[0]  
    embeddings_matrix = np.vstack(df["embeded"].values)  

    similarities = cosine_similarity([query_embedding], embeddings_matrix)[0]
    df = df.copy()  
    df["similarity"] = similarities
    return df.sort_values(by="similarity", ascending=False).head(top_k)

# Użycie
results = search_similar_documents(toche, newdf, model)
print(results[["keywords", "similarity", "title"]])
# Out:
#                                                 keywords  similarity  \
# 18632  [umowa o pracę, porządkowanie prawa, prawo pra...    0.920488
# 12759                      [umowa o pracę, kodeks pracy]    0.919477
# 17064                      [umowa o pracę, kodeks pracy]    0.919477
# 14311  [praca, pracodawca, prawo pracy, zaświadczenia...    0.909734
# 21996  [pracodawca, prawo pracy, kodeks pracy, zatrud...    0.904205
# 21571                [porządkowanie prawa, kodeks pracy]    0.894928
# 22305                [porządkowanie prawa, kodeks pracy]    0.894928
# 18350                [porządkowanie prawa, kodeks pracy]    0.894928
# 19209                [porządkowanie prawa, kodeks pracy]    0.894928
# 20654                [porządkowanie prawa, kodeks pracy]    0.894928
# 20489                [porządkowanie prawa, kodeks pracy]    0.894928
# 19885                [porządkowanie prawa, kodeks pracy]    0.894928
# 19886  [porządkowanie prawa, kodeks pracy, kodeks pos...    0.881906
# 10898       [prawo pracy, tworzenie prawa, kodeks pracy]    0.875677
# 18953  [pracodawca, kodeks pracy, pracownicy, związki...    0.859506
# 20194  [pracodawca, kodeks pracy, pracownicy, związki...    0.859506
# 3673             [praca, świadectwo pracy, kodeks pracy]    0.859203
# 8728             [praca, świadectwo pracy, kodeks pracy]    0.859203
# 11620            [praca, świadectwo pracy, kodeks pracy]    0.859203
# 12097            [praca, świadectwo pracy, kodeks pracy]    0.859203
# 9030             [praca, świadectwo pracy, kodeks pracy]    0.859203
# 19661             [pracodawca, bhp, kodeks pracy, normy]    0.859112
# 9111   [praca, cywilne postępowanie, pracownicy urzęd...    0.854982
# 9969                    [kodeks pracy, związki zawodowe]    0.849042
# 17496                   [kodeks pracy, związki zawodowe]    0.849042
# 18899  [choroby zawodowe, porządkowanie prawa, kodeks...    0.844758
# 6066                          [praca, bhp, kodeks pracy]    0.835865
# 1097   [praca, choroby zawodowe, kodeks pracy, pracow...    0.827386
# 21390                      [bhp, kodeks pracy, nurkowie]    0.826197
# 39        [umowa o pracę, praca, pracodawca, pracownicy]    0.822808
# 252         [praca, dokumenty, kodeks pracy, pracownicy]    0.822781
# 3948        [praca, dokumenty, kodeks pracy, pracownicy]    0.822781
# 3688        [praca, dokumenty, kodeks pracy, pracownicy]    0.822781
# 9736        [praca, dokumenty, kodeks pracy, pracownicy]    0.822781
# 23124  [pracodawca, spory zbiorowe, kodeks pracy, ukł...    0.821226
# 18899    Wyrok Trybunału Konstytucyjnego z dnia 19 czer...
# 6066     Rozporządzenie Ministra Rodziny i Polityki Spo...
# 1097     Rozporządzenie Ministra Zdrowia z dnia 13 wrze...
# 21390    Rozporządzenie Ministra Infrastruktury z dnia ...
# 39       Obwieszczenie Marszałka Sejmu Rzeczypospolitej...
# 252      Rozporządzenie Ministra Rodziny, Pracy i Polit...
# 3948     Rozporządzenie Ministra Rodziny i Polityki Spo...
# 3688     Rozporządzenie Ministra Rodziny i Polityki Spo...
# 9736     Rozporządzenie Ministra Rodziny, Pracy i Polit...
# 23124    Ustawa z dnia 9 listopada 2000 r. o zmianie us...
# 15509    Rozporządzenie Ministra Pracy i Polityki Społe...
# 15924    Wyrok Trybunału Konstytucyjnego z dnia 2 paźdz...
# 15343    Obwieszczenie Prezesa Rady Ministrów z dnia 13...
# 2767     Rozporządzenie Ministra Rozwoju i Technologii ...
# 10869    Rozporządzenie Ministra Rozwoju i Finansów z d...
# 4390     Rozporządzenie Ministra Zdrowia z dnia 12 grud...
# 18917    Rozporządzenie Ministra Pracy i Polityki Społe...
# 20686    Rozporządzenie Ministra Gospodarki i Pracy z d...
# 21072    Rozporządzenie Rady Ministrów z dnia 2 listopa...
# 22500    Rozporządzenie Ministra Pracy i Polityki Społe...
# 21941    Wyrok Trybunału Konstytucyjnego z dnia 17 czer...
# 16130    Rozporządzenie Rady Ministrów z dnia 8 maja 20...
# 16799    Ustawa z dnia 26 maja 2011 r. o zmianie ustawy...
# 19923    Wyrok Trybunału Konstytucyjnego z dnia 28 wrze...
# 21953    Wyrok Trybunału Konstytucyjnego z dnia 10 czer...
# Name: title, dtype: object

# %%
from ai_errors import BadAiApiRes, BadUserPrompt, AiAgentError
from openai import OpenAI
import os
import ai_prompts as aiP


client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

def check_title(title,prompt):
    system_prompt = aiP.prompt_cheack(title,prompt)
                
    response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "system", "content": system_prompt}])
    return response.choices[0].message.content

# %%
arrat=[]
for i, row in results.iterrows():
    t=check_title(row["title"],"Czy pracodawca może rozwiązać umowę o pracę bez wypowiedzenia z powodu nieusprawiedliwionej nieobecności pracownika?")
    if t=="True":
        arrat.append(row)
        print("HU")

# %%
for a in arrat:
    print(a["texts"])
    print(a["address"])

# %%
#https://isap.sejm.gov.pl/isap.nsf/download.xsp/WDU20140001632/O/D20141632.pdf

# %%
import requests


def download_pdf(url):
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
    }


    r = requests.get(url, headers=headers)
    if r.status_code == 200:
        with open("./pobrane_pdf/plik.pdf", "wb") as f:
            f.write(r.content)
    else:
        print("Błąd pobierania", r.status_code)
download_pdf("https://isap.sejm.gov.pl/isap.nsf/download.xsp/WDU20140001632/O/D20141632.pdf")

# %%
import pdfplumber
import re
from sentence_transformers import SentenceTransformer
def extract_text_from_pdf_starting_from_paragraph(pdf_path, start_pattern=r'§\s*1'):
    with pdfplumber.open(pdf_path) as pdf:
        full_text = ""
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                full_text += text + "\n"
        return full_text.strip()
    # match = re.search(start_pattern, full_text)
    # if match:
    #     start_index = match.start()
        # return full_text[start_index:].strip()
    # else:
        
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_text(text, max_words_=300,chunk_overlap_=75):
    splitter = RecursiveCharacterTextSplitter(
    chunk_size=max_words_,          
    chunk_overlap=chunk_overlap_,         
    separators=[r"\n\n", r"\n", r"Art\. ", r"§ "]      
)
    chunks = splitter.split_text(text)
    print(chunks)
    return chunks
def get_text_embeddings(text_chunks, model_name='all-MiniLM-L6-v2'):
    model = SentenceTransformer(model_name)
    embeddings = model.encode(text_chunks, show_progress_bar=True)
    return embeddings

# Użycie:
pdf_file = "plik.pdf"
tekst = extract_text_from_pdf_starting_from_paragraph(pdf_file)

if tekst:
    chunks = split_text(tekst)
    embeddings = get_text_embeddings(chunks)
    print(f"Liczba fragmentów: {len(chunks)}")
    print(f"Embedding pierwszego fragmentu: {embeddings[0]}")
else:
    print("Nie znaleziono paragrafu zaczynającego się od § 1.")
# Out:
# ['DZIENNIK USTAW\nRZECZYPOSPOLITEJ POLSKIEJ\nWarszawa, dnia 24 listopada 2014 r.\nPoz. 1632\nOBWIESZCZENIE\nMINISTRA PRACY I POLITYKI SPOŁECZNEJ\nz dnia 16 września 2014 r.\nw sprawie ogłoszenia jednolitego tekstu rozporządzenia Ministra Pracy i Polityki Socjalnej w sprawie sposobu\nusprawiedliwiania nieobecności w pracy oraz udzielania pracownikom zwolnień od pracy\n1. Na podstawie art. 16 ust. 3 ustawy z dnia 20 lipca 2000 r. o ogłaszaniu aktów normatywnych i niektórych innych\naktów prawnych (Dz. U. z 2011 r. Nr 197, poz. 1172 i Nr 232, poz. 1378) ogłasza się w załączniku do niniejszego\nobwieszczenia jednolity tekst rozporządzenia Ministra Pracy i Polityki Socjalnej z dnia 15 maja 1996 r. w sprawie\nsposobu usprawiedliwiania nieobecności w pracy oraz udzielania pracownikom zwolnień od pracy (Dz. U. Nr 60,\npoz. 281), z uwzględnieniem zmian wprowadzonych:\n1) rozporządzeniem Ministra Pracy i Polityki Społecznej z dnia 29 listopada 2007 r. zmieniającym rozporządzenie\nw sprawie sposobu usprawiedliwiania nieobecności w pracy oraz udzielania pracownikom zwolnień od pracy (Dz. U.\nNr 227, poz. 1678);\n2) rozporządzeniem Ministra Pracy i Polityki Społecznej z dnia 15 września 2011 r. zmieniającym rozporządzenie\nw sprawie sposobu usprawiedliwiania nieobecności w pracy oraz udzielania pracownikom zwolnień od pracy (Dz. U.\nNr 210, poz. 1253);\n3) rozporządzeniem Ministra Pracy i Polityki Społecznej z dnia 15 listopada 2013 r. zmieniającym rozporządzenie\nw sprawie sposobu usprawiedliwiania nieobecności w pracy oraz udzielania pracownikom zwolnień od pracy (Dz. U.\npoz. 1359).\n2. Podany w załączniku do niniejszego obwieszczenia tekst
#   8.09921995e-02  9.80843697e-03  6.02876209e-02  2.76146624e-02
#   3.78247164e-02 -9.58223343e-02  4.73521370e-03 -2.50070938e-03
#  -8.45917538e-02  6.20450005e-02  2.27489602e-02  4.17953283e-02
#   1.22139109e-02 -2.93781515e-02 -2.45288741e-02  1.20229833e-02
#   4.02194336e-02  2.94560054e-03 -2.37678718e-02  1.41266491e-02
#   7.68505409e-02 -8.53196345e-03 -1.17388591e-01 -2.13761386e-02
#  -4.76462170e-02  4.57228627e-03  3.54922637e-02  4.66547981e-02
#   2.18724702e-02 -3.19674797e-02 -1.57916378e-02 -1.08624380e-02
#  -3.89602222e-02 -5.19129857e-02 -9.87990852e-03  9.47922841e-03
#  -2.23198552e-02 -1.89363062e-02 -5.80260418e-02 -2.29672100e-02
#   3.68063599e-02 -7.37962425e-02  4.10907567e-02  5.30019514e-02
#  -6.78434744e-02 -3.00324466e-02 -6.18939660e-02 -5.61608560e-02
#   9.90228057e-02 -4.34658453e-02 -5.28656356e-02  6.55185878e-02
#   5.78367487e-02  4.31963168e-02 -5.86010739e-02  9.40760747e-02
#  -1.30360527e-02  1.29962042e-01 -4.93055992e-02  1.30677978e-02
#   4.47606184e-02  3.52164917e-02 -5.60486242e-02 -7.08433911e-02]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
def search_in_document(question, chunks, embeddings, model_name='all-MiniLM-L6-v2', top_k=10):
    model = SentenceTransformer(model_name)
    question_embedding = model.encode([question])[0]  # embedding pytania

    # Oblicz podobieństwo kosinusowe
    similarities = cosine_similarity([question_embedding], embeddings)[0]

    # Znajdź top k indeksów o największym podobieństwie
    top_indices = similarities.argsort()[-top_k:][::-1]

    # Zwróć top k fragmentów i ich score
    results = [(chunks[i], similarities[i]) for i in top_indices]
    return results

# Przykład użycia:
question = "Czy pracodawca może rozwiązać umowę o pracę bez wypowiedzenia z powodu nieusprawiedliwionej nieobecności pracownika?"
results = search_in_document(question, chunks, embeddings)

for i, (text, score) in enumerate(results):
    print(f"Fragment #{i+1} (similarity: {score:.4f}):\n{text}\n{'-'*40}")
# Out:
# Fragment #1 (similarity: 0.7577):
# § 1. Przyczynami usprawiedliwiającymi nieobecność pracownika w pracy są zdarzenia i okoliczności określone prze-
# pisami prawa pracy, które uniemożliwiają stawienie się pracownika do pracy i jej świadczenie, a także inne przypadki
# niemożności wykonywania pracy wskazane przez pracownika i uznane przez pracodawcę za usprawiedliwiające nieobec-
# ność w pracy.
#
# ----------------------------------------
# Fragment #2 (similarity: 0.7558):
# § 5. Pracodawca jest obowiązany zwolnić od pracy pracownika wezwanego do osobistego stawienia się przed orga-
# nem właściwym w zakresie powszechnego obowiązku obrony na czas niezbędny w celu załatwienia sprawy będącej
# przedmiotem wezwania.
# ----------------------------------------
# Fragment #3 (similarity: 0.7249):
# § 8. Pracodawca jest obowiązany zwolnić od pracy pracownika na czas niezbędny do wzięcia udziału w posiedzeniu
# komisji pojednawczej w charakterze członka tej komisji. Dotyczy to także pracownika będącego stroną lub świadkiem
# w postępowaniu pojednawczym.
# ----------------------------------------
# Fragment #4 (similarity: 0.7226):
# § 12. Pracodawca jest obowiązany zwolnić od pracy pracownika będącego krwiodawcą na czas oznaczony przez sta-
# cję krwiodawstwa w celu oddania krwi. Pracodawca jest również obowiązany zwolnić od pracy pracownika będącego
# krwiodawcą na czas niezbędny do przeprowadzenia zaleconych przez stację krwiodawstwa okresowych badań lekarskich,
# jeżeli nie mogą one być wykonane w czasie wolnym od pracy.
#
# ----------------------------------------
# Fragment #5 (similarity: 0.7209):
# § 11 ust. 1
# pkt 1 i 3, pracodawca wydaje zaświadczenie określające wysokość utraconego wynagrodzenia za czas tego zwolnienia
# w celu uzyskania przez pracownika od właściwego organu rekompensaty pieniężnej z tego tytułu – w wysokości i na wa-
# runkach przewidzianych w odrębnych przepisach, chyba że obowiązujące u danego pracodawcy przepisy prawa pracy
# przewidują zachowanie przez pracownika prawa do wynagrodzenia za czas zwolnienia.
# Rozdział 3
# Przepisy końcowe
#
# ----------------------------------------
# Fragment #6 (similarity: 0.7197):
# § 6. Pracodawca jest obowiązany zwolnić pracownika od pracy na czas niezbędny do stawienia się na wezwanie or-
# ganu administracji rządowej lub samorządu terytorialnego, sądu, prokuratury, policji albo organu prowadzącego postępo-
# wanie w sprawach o wykroczenia.
# ----------------------------------------
# Fragment #7 (similarity: 0.7061):
# § 17. 1. Traci moc rozporządzenie Rady Ministrów z dnia 20 grudnia 1974 r. w sprawie regulaminów pracy oraz za-
# sad usprawiedliwiania nieobecności w pracy i udzielania zwolnień od pracy (Dz. U. Nr 49, poz. 299, z późn. zm.7)),
# z zastrzeżeniem ust. 2.
# 2. Do pracowników przebywających w areszcie tymczasowym w dniu wejścia w życie niniejszego rozporządzenia
# stosuje się uprawnienia wynikające z
# ----------------------------------------
# Fragment #8 (similarity: 0.6995):
# § 7. Pracodawca jest obowiązany zwolnić od pracy pracownika wezwanego w celu wykonywania czynności biegłego
# w postępowaniu administracyjnym, karnym przygotowawczym, sądowym lub przed kolegium do spraw wykroczeń; łącz-
# ny wymiar zwolnień z tego tytułu nie może przekraczać 6 dni w ciągu roku kalendarzowego.
#
# ----------------------------------------
# Fragment #9 (similarity: 0.6840):
# § 13. 1. Pracodawca jest obowiązany zwolnić od pracy pracownika w celu przeprowadzenia zajęć dydaktycznych
# w szkole zawodowej, w szkole wyższej, w placówce naukowej albo w jednostce badawczo-rozwojowej; łączny wymiar
# zwolnień z tego tytułu nie może przekraczać 6 godzin w tygodniu lub 24 godzin w miesiącu.
# 2. Przepis ust. 1 stosuje się odpowiednio do pracownika w razie prowadzenia szkolenia na kursie zawodowym.
#
# ----------------------------------------
# Fragment #10 (similarity: 0.6804):
# § 10. Pracodawca jest obowiązany zwolnić od pracy pracownika wezwanego w charakterze świadka w postępowaniu
# kontrolnym prowadzonym przez Najwyższą Izbę Kontroli i pracownika powołanego do udziału w tym postępowaniu
# w charakterze specjalisty.
# ----------------------------------------
